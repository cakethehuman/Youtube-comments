# %%
import pandas as pd
import numpy as np
import joblib

# %%
df1 = joblib.load("..\data\internim\X_train_clean.pkl")
df2 = joblib.load("..\data\internim\y_train.pkl")

df = pd.concat([df1,df2], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17624 entries, 0 to 15795
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Comments   14248 non-null  object
#  1   Sentiment  14726 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 413.1+ KB

# %%
df
# Out:
#                                                 Comments  Sentiment
# 0      subscribe ill kick also dont forget starting r...        NaN
# 1      hey thats really great tutorial minutes took t...        0.0
# 2                                thanks great work folks        2.0
# 3      la relajaci n es importante kissxuno los morta...        NaN
# 4      literature review definition critical recap al...        2.0
# ...                                                  ...        ...
# 2747                                                 NaN        2.0
# 17568                                                NaN        2.0
# 16023                                                NaN        2.0
# 16850                                                NaN        2.0
# 15795                                                NaN        1.0
#
# [17624 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import defaultdict

world_List = defaultdict(int)

for words in df["Comments"]:
    for kata in str(words).split(" "):
        world_List[str(kata).strip()] += 1


genres_cloud = WordCloud(width=1000, height=600, 
                         background_color='black', colormap='RdBu',max_words=20).generate_from_frequencies(world_List)
plt.imshow(genres_cloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common words in comments")
# Out:
# Text(0.5, 1.0, 'Common words in comments')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import defaultdict

world_List = defaultdict(int)

for words in df["Comments"][df["Sentiment"] == 1]:
    for kata in str(words).split(" "):
        world_List[str(kata).strip()] += 1


genres_cloud = WordCloud(width=1000, height=600, 
                         background_color='black', colormap='RdBu',max_words=20).generate_from_frequencies(world_List)
plt.imshow(genres_cloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common words in comments labeled as neutral")
# Out:
# Text(0.5, 1.0, 'Common words in comments labeled as neutral')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import defaultdict

world_List = defaultdict(int)

for words in df["Comments"][df["Sentiment"] == 0]:
    for kata in str(words).split(" "):
        world_List[str(kata).strip()] += 1


genres_cloud = WordCloud(width=1000, height=600, 
                         background_color='black', colormap='RdBu',max_words=20).generate_from_frequencies(world_List)
plt.imshow(genres_cloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common words in comments labeled as negative")
# Out:
# Text(0.5, 1.0, 'Common words in comments labeled as negative')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import defaultdict

world_List = defaultdict(int)

for words in df["Comments"][df["Sentiment"] == 2]:
    for kata in str(words).split(" "):
        world_List[str(kata).strip()] += 1


genres_cloud = WordCloud(width=1000, height=600, 
                         background_color='black', colormap='RdBu',max_words=20).generate_from_frequencies(world_List)
plt.imshow(genres_cloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common words in comments labeled as positive")
# Out:
# Text(0.5, 1.0, 'Common words in comments labeled as positive')
