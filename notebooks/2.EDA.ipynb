# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_pickle(r"..\data\internim\X_train_clean.pkl")
df1 = pd.DataFrame(df1.T, columns = ["Comments"])

# %%
df = pd.concat([df1], axis= 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14248 entries, 0 to 14247
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Comments  14248 non-null  object
# dtypes: object(1)
# memory usage: 111.4+ KB

# %%
df
# Out:
#                                                 Comments
# 0      subscribe ill kick also dont forget starting r...
# 1      hey thats really great tutorial minutes took t...
# 2                                thanks great work folks
# 3      la relajaci n es importante kissxuno los morta...
# 4      literature review definition critical recap al...
# ...                                                  ...
# 14243  one thing proof mankind lot smarter lot advanc...
# 14244  education used separate maintain social classe...
# 14245  emotional experience know feels like life dang...
# 14246  take moment appreciate much time effort put vi...
# 14247  yeah buy rechargeable battery pack xb controll...
#
# [14248 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import defaultdict

world_List = defaultdict(int)

for words in df["Comments"]:
    for kata in str(words).split(" "):
        world_List[str(kata).strip()] += 1


genres_cloud = WordCloud(width=1000, height=600, 
                         background_color='black', colormap='RdBu',max_words=20).generate_from_frequencies(world_List)
plt.imshow(genres_cloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common words in comments")
# Out:
# Text(0.5, 1.0, 'Common words in comments')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import defaultdict

world_List = defaultdict(int)

for words in df["Comments"]:
    for kata in str(words).split(" "):
        world_List[str(kata).strip()] += 1


genres_cloud = WordCloud(width=1000, height=600, 
                         background_color='black', colormap='RdBu',max_words=20).generate_from_frequencies(world_List)
plt.imshow(genres_cloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common words in comments")
# Out:
# Text(0.5, 1.0, 'Common words in comments')
